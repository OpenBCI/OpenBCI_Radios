# %%
import numpy as np
import pandas as pd
from pylab import plt
# %matplotlib inline

# %%
data = pd.read_csv('../js/results/timeSyncTest-samples5SyncLocal5.csv')
mmn_timestamps = pd.read_csv('../js/results/MMN_timestamp5SyncLocal5.csv')

# %%
plt.plot(data['Sensor Value'][0:2000])

# %%
X = []
window = 100
offset = 10
sfreq = 250.0
times = np.linspace(-offset/sfreq, window/sfreq, window + offset)
for i in mmn_timestamps.timestamp.values:
    ix = np.where(data['Time Stamp'] > i)[0]
    if len(ix)>0:
        ix = ix[0]
        X.append(data.loc[(ix - offset):(ix + window - 1), 'Sensor Value'])
X = np.array(X[1:-1], dtype=np.float64)

# baseline correction
X -= np.atleast_2d(X[:, 0:offset].mean(1)).T
# normalization
X /= np.atleast_2d(X.max(1)).T

# %% [markdown]
# Now each line below is a stimulus

# %%
plt.plot(1000*times, X.T);
plt.title('Trial 5 with 5 Syncs on Local Time')
plt.xlabel('time (ms)')

# %% [markdown]
# We can also show it as a picture

# %%
plt.imshow(X)

# %% [markdown]
# We can also quantify it, here we detect when the signal > 300 and plot the histogram

# %%
delays  = []
delays_off = []
for x in X:
    d = np.where(x>0.1)[0][0]
    delays.append(1000*times[d])
    d = np.where(x>0.9)[0][-1]
    delays_off.append(1000*times[d])
plt.hist(delays)
plt.xlabel('Delays (ms)')

# %% [markdown]
# to see the delays from drift

# %%
plt.plot(delays)
plt.ylabel('delay (ms)')
plt.xlabel('stimulus index')
plt.title('Delay as a function of time')
